# %% [markdown]
# <h6 align=right> 🐍 Python akademie - lekce 2 - DD.MM.YYYY</h6>

# %% [markdown]
# <br>
#
# # <h1 align=center><font color=black size=24><b> 02_00: Opakování 1. lekce</font></h1>
#
# <br>
#
# ---

# %%
print(2 * 3 / 2 ** 2) # prvni umocneni, pak zbytek
# Out:
# 1.5

# %%
print(2 ** 2 / 3 * 2)
# Out:
# 2.6666666666666665

# %%
print(2 + 2)
# Out:
# 4

# %%
print("2" + "2")
# Out:
# 22

# %%
print(11 * 2)
# Out:
# 22

# %%
print(11 * "2")
# Out:
# 22222222222

# %%
print(1 * 2 * 3 * "x")
# Out:
# xxxxxx

# %%
print(2 + 1*11*"x")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9e9bfa0632dd> in <cell line: 0>()
# ----> 1 print(2 + 1*11*"x")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print("It\'s\n\"kind of\"\nfriday")
# Out:
# It's
# "kind of"
# friday

# %%
print(type(int(input("Zadej ciselny znak:"))))
# Out:
# Zadej ciselny znak:5
# <class 'int'>

# %% [markdown]
# <br>
#
# ## **Práce s listy, indexování**

# %%
JMENA = ["Matous", "Marek", "Lukas", "Jan"]

# %%
print(JMENA[-1])
# Out:
# Jan

# %%
print(JMENA[-2])
# Out:
# Lukas

# %%
print(JMENA[8 % 6])
# Out:
# Lukas

# %%
print(JMENA[0 % 6])
# Out:
# Matous

# %%
print(0 % 5)
# Out:
# 0

# %%
JMENA = ["Matous", "Marek", "Lukas", "Jan"]

# %%
JMENA[0:2]
# Out:
# ['Matous', 'Marek']

# %%
JMENA[:2]
# Out:
# ['Matous', 'Marek']

# %%
JMENA[1::2]
# Out:
# ['Marek', 'Jan']

# %%
JMENA[1:4:2]
# Out:
# ['Marek', 'Jan']

# %%
len(JMENA)
# Out:
# 4

# %%
posledni_index = len(JMENA) - 1

# %%
JMENA[posledni_index]
# Out:
# 'Jan'
